# %% [markdown]
# <a href="https://colab.research.google.com/github/PurdueCho/Colab/blob/master/g_25_%ED%81%B4%EB%9F%AC%EC%8A%A4%ED%84%B0%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 클러스터링
# ==
# ## kMeans, DBSCAN 비교
# 데이터
# --
# - 전력판매량(시도별/용도별) 액셀 파일 https://goo.gl/Cx8Rzw
# - 위 자료는 전력거래소에서 받은 자료임
# - 이 파일을 현재 작업중인 (쥬피터 노트북이 실행되는) 폴더 아래에 data 폴더를 만들고 data 폴더로 복사한다

# %% [markdown]
# ## 한글 폰트 설치

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# '-' 기호 보이게 하기
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %% [markdown]
# ## 여기서 런타임 - 런타임 다시 시작을 실행한 후에 위의 코드를 다시한번 실행하여야 한다

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = range(100)
y = np.random.rand(100)
plt.scatter(x,y)
plt.xlabel('x 축입니다')
plt.ylabel('y 축입니다')
# Out:
# Text(0, 0.5, 'y 축입니다')

# %% [markdown]
# 필요한 라이브러리(모듈) 설치
# --

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# 데이터 다운로드
import os, os.path, shutil
if not os.path.exists("./data"):
    os.makedirs("./data")
# !wget https://goo.gl/Cx8Rzw -O ./data/power.xls
# Out:
# --2020-04-09 07:32:39--  https://goo.gl/Cx8Rzw
# Resolving goo.gl (goo.gl)... 74.125.139.138, 74.125.139.100, 74.125.139.102, ...
# Connecting to goo.gl (goo.gl)|74.125.139.138|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/s/w9m6n2zbl2986of/%EC%8B%9C%EB%8F%84%EB%B3%84_%EC%9A%A9%EB%8F%84%EB%B3%84.xls?dl=0 [following]
# --2020-04-09 07:32:39--  https://www.dropbox.com/s/w9m6n2zbl2986of/%EC%8B%9C%EB%8F%84%EB%B3%84_%EC%9A%A9%EB%8F%84%EB%B3%84.xls?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/w9m6n2zbl2986of/%EC%8B%9C%EB%8F%84%EB%B3%84_%EC%9A%A9%EB%8F%84%EB%B3%84.xls [following]
# --2020-04-09 07:32:39--  https://www.dropbox.com/s/raw/w9m6n2zbl2986of/%EC%8B%9C%EB%8F%84%EB%B3%84_%EC%9A%A9%EB%8F%84%EB%B3%84.xls
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com/cd/0/inline/A1jfaSKpPf_uxWnnmkYhWkfDrmPmgAzp822GxwV2ZFj9_VCa0xD-brPTA11QvR3zhN6Q7RirRpisYDyscAuCyLiQ8DbbhBBufTkfeaK4ie7Y3A/file# [following]
# --2020-04-09 07:32:39--  https://uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com/cd/0/inline/A1jfaSKpPf_uxWnnmkYhWkfDrmPmgAzp822GxwV2ZFj9_VCa0xD-brPTA11QvR3zhN6Q7RirRpisYDyscAuCyLiQ8DbbhBBufTkfeaK4ie7Y3A/file
# Resolving uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com (uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601b:6::a27d:806
# Connecting to uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com (uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/A1ibVIDm43Ts1ibQNSrthzF8yffo34JYn36WdUc4V39TcyHJgS0WPT26leFuDL-QZNWX0mIaXeiwUQI2PsS-wrgZjIyxcXJdrWcLPGCYKx8OetI6VpZC3TZ0_hEFDy1iGCa1ZAGthSTMTWbDRVbmdnGhrOYs6w8bsPZPQvi0Av8wRuy2zuQdmc2xWyC2iwUjECqFMknr_CZHYGAaVwJsEA2VUGB8cVuTgP9lWgT7hx7-QAsnl4LJYxhB93GXwPO3rV6NKqn5n2FaS0L8iGY_l1ZAcbYkfxZBhFtN2Rci_c6n5UbGLOcsng5bHoj2wfqx_adriIqu0uJbotvPfW3s8sW-/file [following]
# --2020-04-09 07:32:40--  https://uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com/cd/0/inline2/A1ibVIDm43Ts1ibQNSrthzF8yffo34JYn36WdUc4V39TcyHJgS0WPT26leFuDL-QZNWX0mIaXeiwUQI2PsS-wrgZjIyxcXJdrWcLPGCYKx8OetI6VpZC3TZ0_hEFDy1iGCa1ZAGthSTMTWbDRVbmdnGhrOYs6w8bsPZPQvi0Av8wRuy2zuQdmc2xWyC2iwUjECqFMknr_CZHYGAaVwJsEA2VUGB8cVuTgP9lWgT7hx7-QAsnl4LJYxhB93GXwPO3rV6NKqn5n2FaS0L8iGY_l1ZAcbYkfxZBhFtN2Rci_c6n5UbGLOcsng5bHoj2wfqx_adriIqu0uJbotvPfW3s8sW-/file
# Reusing existing connection to uc6f0f124172a98da7866e9a82c6.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 17920 (18K) [application/vnd.ms-excel]
# Saving to: ‘./data/power.xls’
#
# ./data/power.xls    100%[===================>]  17.50K  --.-KB/s    in 0s
#
# 2020-04-09 07:32:40 (208 MB/s) - ‘./data/power.xls’ saved [17920/17920]

# %% [markdown]
# 데이터 읽기
# --

# %%
power_data = pd.read_excel('data/power.xls')
print(power_data.shape)
# Out:
# (19, 28)

# %%
power = power_data.set_index('구분')

# %%
power = power.drop(['합계', '개성'], errors='ignore')

# %%
power = power.drop('합계', axis=1)

# %%
power = power[['서비스업', '제조업']]
power.head(5)
# Out:
#         서비스업       제조업
# 구분
# 강원   6203749   6002286
# 경기  33434551  56603327
# 경남   8667737  18053778
# 경북   8487402  30115601
# 광주   3174973   2910768

# %% [markdown]
# 스캐터 플롯
# --

# %%
plt.figure(figsize=(8,8))
plt.scatter(power['서비스업'], power['제조업'],c='k',marker='o')
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(power.shape[0]):
    plt.text(power['서비스업'][n]*1.03, power['제조업'][n]*0.98, power.index[n])

# %%
power = power.drop(['경기', '서울'])

# %%
plt.figure(figsize=(8,8))
plt.scatter(power['서비스업'], power['제조업'],c='k',marker='o')
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(power.shape[0]):
    plt.text(power['서비스업'][n]*1.03, power['제조업'][n]*0.98, power.index[n])

# %% [markdown]
# # 클러스터링

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
link_dist = linkage(power, metric='euclidean', method='ward')  
dendrogram(link_dist, labels=power.index)
plt.show()

# %%
from sklearn.cluster import KMeans
k = KMeans(n_clusters=6).fit(power)
print(k.n_clusters)
# Out:
# 6

# %%
power['클러스터'] = k.labels_
power.head(10)
# Out:
#        서비스업       제조업  클러스터
# 구분
# 강원  6203749   6002286     3
# 경남  8667737  18053778     1
# 경북  8487402  30115601     5
# 광주  3174973   2910768     0
# 대구  5470438   5862633     3
# 대전  3955921   2608343     0
# 부산  7582169   7512588     3
# 세종   645424   1502922     0
# 울산  3649386  25883132     5
# 인천  7154416  12367816     4

# %%
power.drop('클러스터', axis = 1, inplace=True) ; power.head()
# Out:
#        서비스업       제조업
# 구분
# 강원  6203749   6002286
# 경남  8667737  18053778
# 경북  8487402  30115601
# 광주  3174973   2910768
# 대구  5470438   5862633

# %%
centers = k.cluster_centers_ ; centers
# Out:
# array([[ 2521262.5       ,  1815892.5       ],
#        [ 7179198.        , 19753852.        ],
#        [ 7164439.        , 37057955.        ],
#        [ 6418785.33333333,  6459169.        ],
#        [ 5623124.        , 13739046.33333333],
#        [ 6068394.        , 27999366.5       ]])

# %%
my_markers=['*','^', 'o','^','.',',','1','2']
my_color =['r','c','g','b','g','k','r','y']

plt.figure(figsize=(10, 8))
plt.xlabel('서비스업')
plt.ylabel('제조업')
for n in range(power.shape[0]):
    label = k.labels_[n]
    plt.scatter(power['서비스업'][n], power['제조업'][n], c=my_color[label], marker=my_markers[label], s=100)
    plt.text(power['서비스업'][n]*1.03, power['제조업'][n]*0.98, power.index[n])
    
for i in range(k.n_clusters):
    plt.scatter(centers[i][0], centers[i][1], c = 'r', s= 50)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
power[['서비스업', '제조업']] = scaler.fit_transform(power[['서비스업', '제조업']])
power
# Out:
#         서비스업       제조업
# 구분
# 강원  0.393992 -0.676282
# 경남  1.498349  0.431200
# 경북  1.417523  1.539632
# 광주 -0.963503 -0.960380
# 대구  0.065323 -0.689116
# 대전 -0.613482 -0.988171
# 부산  1.011798 -0.537491
# 세종 -2.097244 -1.089755
# 울산 -0.750871  1.150686
# 인천  0.820080 -0.091316
# 전남  0.164025  0.743660
# 전북 -0.185723 -0.036357
# 제주 -1.351751 -1.205671
# 충남  0.824572  2.177606
# 충북 -0.233088  0.231756

# %%
Z = linkage(power, metric='euclidean', method='ward') 
# 유클리드 거리를 이용해 Linkage Matrix를 생성
plt.figure(figsize=(10, 5))
plt.title('덴드로그램')
dendrogram(Z, labels=power.index)
plt.show()

# %%
k = KMeans(n_clusters= 4).fit(power)
centers = k.cluster_centers_

# %%
plt.clf()
plt.figure(figsize=(10, 8))
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(power.shape[0]):
    label = k.labels_[n]
    plt.scatter(power['서비스업'][n], power['제조업'][n], c=my_color[label], marker=my_markers[label], s=100)
    plt.text(power['서비스업'][n]*1.05, power['제조업'][n]*0.99, power.index[n])
    
for i in range(k.n_clusters):
    plt.scatter(centers[i][0], centers[i][1], c = 'r', s= 50)

# %%
# 모든 특성 고려
power_data.head().T
# Out:
#               0   1          2         3         4
# 구분           강원  개성         경기        경남        경북
# 주거용     1940933   0   16587710   4260988   3302463
# 공공용     1400421   0    5533662   1427560   1578115
# 서비스업    6203749   0   33434551   8667737   8487402
# 업무용합계   7604170   0   38968213  10095297  10065517
# 농림어업     607139   0    2371347   2141813   1747462
# 광업       398287   0     317263     95989    224568
# 제조업     6002286   0   56603327  18053778  30115601
# 식료품제조    546621   0    2544420    932743    566071
# 섬유,의류     13027   0    2109963    346974   3780171
# 목재,나무     19147   0     529274     60160     72680
# 펄프,종이     24382   0    1917458    817685    361772
# 출판,인쇄      7727   0     731348     28486     44402
# 석유,화확    175323   0    6881775   1865583   3653665
# 의료,광학     84397   0    1336390    178498    217771
# 요업      3695776   0    1728379    429920   1269917
# 1차금속    1038913   0    2020196   3809547  10874970
# 조립금속      39477   0    2302355   1699879    933178
# 기타기계      35063   0    3613798   1902913    782570
# 사무기기       2019   0     317244      8070     14468
# 전기기기      38062   0    1040171    924235    750786
# 영상,음향     43986   0   24519644    534196   4174971
# 자동차      113448   0    2977165   2156059   2356890
# 기타운송     108629   0      67594   2048646    123935
# 가구및기타     12872   0    1833112    262523     60280
# 재생재료       3418   0     133041     47662     77104
# 산업용합계   7007712   0   59291937  20291580  32087631
# 합계     16552816   0  114847859  34647864  45455611

# %%
power2 = power_data.set_index('구분')
power2.drop(['업무용합계', '산업용합계', '합계'], axis=1, 
           inplace=True, errors='ignore')
power2.drop(['합계','개성','경기','서울'], inplace=True,errors='ignore')

# %%
power2
# Out:
#         주거용      공공용     서비스업     농림어업  ...      자동차     기타운송   가구및기타   재생재료
# 구분                                      ...
# 강원  1940933  1400421  6203749   607139  ...   113448   108629   12872   3418
# 경남  4260988  1427560  8667737  2141813  ...  2156059  2048646  262523  47662
# 경북  3302463  1578115  8487402  1747462  ...  2356890   123935   60280  77104
# 광주  1954876   565527  3174973    74608  ...   512148     5140   13392  16049
# 대구  3151904   826396  5470438    69142  ...  1381273    68127   41814  33616
# 대전  1872890   954681  3955921    28643  ...   218191     5439   31657   2252
# 부산  4473510  1305876  7582169   107927  ...  1046529   231141   49733  13104
# 세종   384903   299675   645424    69469  ...    79009        0    5132   2603
# 울산  1487143   489865  3649386    80221  ...  2367150  1020610    4984   1626
# 인천  3856852   921748  7154416   142953  ...   612898    54225  360778  32538
# 전남  2284124   964024  5690659  3096126  ...    72132   481592   14670  31932
# 전북  2326183  1096968  4910318  1415004  ...   859741    70980   16175  99003
# 제주   782601   301727  2308732  1364930  ...      773      532    1743    743
# 충남  2691823  1089613  7164439  1928066  ...  2526658    33766   53804  19725
# 충북  2027281  1267140  4804638   721131  ...   603349    82496  513501  46038
#
# [15 rows x 24 columns]

# %%
power3 = pd.DataFrame(scaler.fit_transform(power2), columns=power2.columns,
                      index=power2.index)

Z = linkage(power3, metric='euclidean', method='ward') 
# 유클리드 거리를 이용해 Linkage Matrix를 생성
plt.figure(figsize=(10, 5))
plt.title('덴드로그램')
dendrogram(Z, labels=power3.index)
plt.show()

# %%
k = KMeans(n_clusters=8).fit(power3)
n_samples = power3.shape[0]
print(n_samples)

plt.figure(figsize=(10, 8))
plt.xlabel('서비스업')
plt.ylabel('제조업')

for n in range(n_samples):
    label = k.labels_[n]
    plt.scatter(power3['서비스업'][n], power3['제조업'][n], c=my_color[label], marker=my_markers[label], s=100)
    plt.text(power3['서비스업'][n]*1.05, power3['제조업'][n]*0.99, power3.index[n])
# Out:
# 15

# %%
power3
# Out:
#          주거용       공공용      서비스업  ...      기타운송     가구및기타      재생재료
# 구분                                ...
# 강원 -0.447461  1.107363  0.393992  ... -0.336181 -0.556318 -0.886117
# 경남  1.578961  1.176534  1.498349  ...  3.279342  1.110336  0.677332
# 경북  0.741750  1.560268  1.417523  ... -0.307656 -0.239826  1.717722
# 광주 -0.435282 -1.020610 -0.963503  ... -0.529049 -0.552847 -0.439775
# 대구  0.610246 -0.355709  0.065323  ... -0.411663 -0.363103  0.180989
# 대전 -0.506892 -0.028737 -0.613482  ... -0.528492 -0.430911 -0.927319
# 부산  1.764586  0.866387  1.011798  ... -0.107861 -0.310237 -0.543843
# 세종 -1.806555 -1.698213 -2.097244  ... -0.538628 -0.607990 -0.914916
# 울산 -0.843818 -1.213457 -0.750871  ...  1.363437 -0.608978 -0.949440
# 인천  1.225974 -0.112676  0.820080  ... -0.437572  1.766281  0.142896
# 전남 -0.147705 -0.004924  0.164025  ...  0.358893 -0.544315  0.121481
# 전북 -0.110969  0.333923 -0.185723  ... -0.406346 -0.534268  2.491566
# 제주 -1.459191 -1.692982 -1.351751  ... -0.537637 -0.630615 -0.980643
# 충남  0.208395  0.315177  0.824572  ... -0.475700 -0.283059 -0.309877
# 충북 -0.372041  0.767657 -0.233088  ... -0.384884  2.785850  0.619944
#
# [15 rows x 24 columns]

# %% [markdown]
# ## 클러스터링 비교

# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
X, y = make_moons(n_samples=300, noise=0.05, random_state=11)
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
kmeans = KMeans(n_clusters=2)
predict = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)

# %%
dbscan = DBSCAN(eps=0.2, min_samples=10, metric='euclidean')
predict = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)

# %%
dbscan = DBSCAN(eps=0.1, min_samples=5, metric='euclidean')
predict = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)

# %%
dbscan = DBSCAN(eps=0.1, min_samples=10, metric='euclidean')
predict = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)

# %%
dbscan = DBSCAN(eps=0.5, min_samples=10, metric='euclidean')
predict = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)

# %%
dbscan = DBSCAN(eps=0.2, min_samples=6, metric='euclidean')
predict = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)

# %%
dbscan = DBSCAN(eps=0.2, min_samples=15, metric='euclidean')
predict = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1],c=predict)
